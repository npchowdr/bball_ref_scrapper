# %%
years = list(range(1980,2022))

# %%
url_start = "https://www.basketball-reference.com/leagues/NBA_{}_per_poss.html"

# %%
import requests

for year in years:
    url = url_start.format(year)
    data = requests.get(url)
    
    with open("playerPer100PosStats/{}.html".format(year), "w", encoding="utf-8") as f:
        f.write(data.text)

# %%
from bs4 import BeautifulSoup

# %%
with open("playerPer100PosStats/1991.html") as f:
    page = f.read()

# %%
soup = BeautifulSoup(page, "html.parser")

# %%
list_decompose = soup.find_all('tr', class_="thead")
for item in list_decompose:
    item.decompose()
    #list_decompose[item].decompose()

# %%
stats_table = soup.find(id="per_poss_stats")

# %%
import pandas as pd

# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-1.4.1-cp39-cp39-macosx_10_9_x86_64.whl (11.5 MB)
#      |████████████████████████████████| 11.5 MB 731 kB/s
# Requirement already satisfied: pytz>=2020.1 in /Users/nchowdri/opt/miniconda3/envs/atmcore/lib/python3.9/site-packages (from pandas) (2020.1)
# Collecting numpy>=1.18.5
#   Using cached numpy-1.22.2-cp39-cp39-macosx_10_14_x86_64.whl (17.6 MB)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/nchowdri/opt/miniconda3/envs/atmcore/lib/python3.9/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: six>=1.5 in /Users/nchowdri/opt/miniconda3/envs/atmcore/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas) (1.15.0)
# Installing collected packages: numpy, pandas
# Successfully installed numpy-1.22.2 pandas-1.4.1
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the '/Users/nchowdri/opt/miniconda3/envs/atmcore/bin/python -m pip install --upgrade pip' command.

# %%
stats_1991 = pd.read_html(str(stats_table))[0]

# %%
stats_1991
# Out:
#       Rk              Player Pos  Age   Tm   G    MP   PER    TS%   3PAr  ...  \
# 0      1      Alaa Abdelnaby  PF   22  POR  43   290  13.1  0.499  0.000  ...
# 1      2  Mahmoud Abdul-Rauf  PG   21  DEN  67  1505  12.2  0.448  0.099  ...
# 2      3          Mark Acres   C   28  ORL  68  1313   9.2  0.551  0.014  ...
# 3      4       Michael Adams  PG   28  DEN  66  2346  22.3  0.530  0.397  ...
# 4      5        Mark Aguirre  SF   31  DET  78  2006  16.7  0.526  0.086  ...
# ..   ...                 ...  ..  ...  ...  ..   ...   ...    ...    ...  ...
# 436  385       Howard Wright  PF   23  ATL   4    20   6.3  0.727  0.000  ...
# 437  385       Howard Wright  PF   23  ORL   8   136   7.5  0.428  0.000  ...
# 438  385       Howard Wright  PF   23  DAL   3     8  34.8  0.773  0.333  ...
# 439  386         A.J. Wynder  PG   26  BOS   6    39   7.6  0.387  0.083  ...
# 440  387         Danny Young  PG   28  POR  75   897  11.7  0.487  0.384  ...
#
#      Unnamed: 19  OWS  DWS   WS  WS/48  Unnamed: 24  OBPM  DBPM   BPM  VORP
# 0            NaN  0.0  0.5  0.5  0.079          NaN  -3.4  -1.2  -4.6  -0.2
# 1            NaN -0.7 -0.3 -1.0 -0.031          NaN  -2.0  -3.0  -5.0  -1.1
# 2            NaN  1.4  1.1  2.5  0.090          NaN  -2.8  -0.2  -3.0  -0.3
# 3            NaN  5.8  0.4  6.3  0.128          NaN   6.0  -0.7   5.3   4.3
# 4            NaN  2.8  2.7  5.5  0.132          NaN   1.2   0.2   1.4   1.7
# ..           ...  ...  ...  ...    ...          ...   ...   ...   ...   ...
# 436          NaN  0.0  0.0  0.0  0.013          NaN  -5.0  -1.4  -6.4   0.0
# 437          NaN -0.2  0.1  0.0 -0.003          NaN  -5.6  -0.7  -6.3  -0.1
# 438          NaN  0.1  0.0  0.1  0.478          NaN   6.7   4.4  11.0   0.0
# 439          NaN -0.1  0.0  0.0 -0.051          NaN  -2.6  -2.7  -5.3   0.0
# 440          NaN  0.6  1.2  1.8  0.096          NaN  -0.6   1.1   0.5   0.6
#
# [441 rows x 29 columns]

# %%
dfs = []
for year in years:
    with open("playerAdvancedStats/{}.html".format(year)) as f:
        page = f.read()
        soup = BeautifulSoup(page, "html.parser")
        
        list_decompose = soup.find_all('tr', class_="thead")
        for item in list_decompose:
            item.decompose()
            
#         list_decompose = soup.find_all('tr', class_=None)
#         for item in list_decompose:
#             item.decompose() 
        
        stats_table = soup.find(id="advanced_stats")
        stats = pd.read_html(str(stats_table))[0]
        stats["Year"] = year
        dfs.append(stats)

# %%
dfs[0]
# Out:
#       Rk                Player Pos  Age   Tm   G    MP   PER    TS%   3PAr  \
# 0      1  Kareem Abdul-Jabbar*   C   32  LAL  82  3143  25.3  0.639  0.001
# 1      2         Tom Abernethy  PF   25  GSW  67  1222  11.0  0.511  0.003
# 2      3           Alvan Adams   C   25  PHO  75  2168  19.2  0.571  0.002
# 3      4       Tiny Archibald*  PG   31  BOS  80  2864  15.3  0.574  0.023
# 4      5         Dennis Awtrey   C   31  CHI  26   560   7.4  0.524  0.000
# ..   ...                   ...  ..  ...  ...  ..   ...   ...    ...    ...
# 352  283          Bubba Wilson  SG   24  GSW  16   143   2.1  0.308  0.000
# 353  284           Rick Wilson  SG   23  ATL   5    59   2.0  0.240  0.000
# 354  285         Brian Winters  SG   27  MIL  80  2623  14.8  0.534  0.091
# 355  286          Larry Wright  PG   25  WSB  76  1286  13.3  0.510  0.032
# 356  287             Tony Zeno  SF   22  IND   8    59   0.2  0.320  0.000
#
#      ...  OWS  DWS    WS  WS/48  Unnamed: 24  OBPM  DBPM  BPM  VORP  Year
# 0    ...  9.5  5.3  14.8  0.227          NaN   4.8   2.4  7.2   7.3  1980
# 1    ...  1.2  0.8   2.0  0.080          NaN  -1.0  -0.2 -1.2   0.2  1980
# 2    ...  3.1  3.9   7.0  0.155          NaN   1.7   1.9  3.6   3.1  1980
# 3    ...  5.9  2.9   8.9  0.148          NaN   1.4  -0.3  1.1   2.3  1980
# 4    ...  0.1  0.5   0.6  0.053          NaN  -2.3   0.9 -1.4   0.1  1980
# ..   ...  ...  ...   ...    ...          ...   ...   ...  ...   ...   ...
# 352  ... -0.2  0.0  -0.2 -0.064          NaN  -4.4  -0.9 -5.3  -0.2  1980
# 353  ... -0.3  0.1  -0.2 -0.146          NaN  -4.1   0.0 -4.1   0.0  1980
# 354  ...  3.6  2.6   6.2  0.113          NaN   0.3  -0.2  0.2   1.4  1980
# 355  ...  0.8  1.0   1.8  0.069          NaN  -1.1   0.1 -1.0   0.3  1980
# 356  ... -0.3  0.1  -0.2 -0.160          NaN  -6.4  -0.1 -6.5  -0.2  1980
#
# [357 rows x 30 columns]

# %%
dfs[0].columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'MP', 'PER', 'TS%', '3PAr',
#        'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%',
#        'Unnamed: 19', 'OWS', 'DWS', 'WS', 'WS/48', 'Unnamed: 24', 'OBPM',
#        'DBPM', 'BPM', 'VORP', 'Year'],
#       dtype='object')

# %%
player_stats = pd.concat(dfs)

# %%
player_stats.head()
# Out:
#    Rk                Player Pos  Age   Tm   G    MP   PER    TS%   3PAr  ...  \
# 0   1  Kareem Abdul-Jabbar*   C   32  LAL  82  3143  25.3  0.639  0.001  ...
# 1   2         Tom Abernethy  PF   25  GSW  67  1222  11.0  0.511  0.003  ...
# 2   3           Alvan Adams   C   25  PHO  75  2168  19.2  0.571  0.002  ...
# 3   4       Tiny Archibald*  PG   31  BOS  80  2864  15.3  0.574  0.023  ...
# 4   5         Dennis Awtrey   C   31  CHI  26   560   7.4  0.524  0.000  ...
#
#    OWS  DWS    WS  WS/48  Unnamed: 24  OBPM  DBPM  BPM  VORP  Year
# 0  9.5  5.3  14.8  0.227          NaN   4.8   2.4  7.2   7.3  1980
# 1  1.2  0.8   2.0  0.080          NaN  -1.0  -0.2 -1.2   0.2  1980
# 2  3.1  3.9   7.0  0.155          NaN   1.7   1.9  3.6   3.1  1980
# 3  5.9  2.9   8.9  0.148          NaN   1.4  -0.3  1.1   2.3  1980
# 4  0.1  0.5   0.6  0.053          NaN  -2.3   0.9 -1.4   0.1  1980
#
# [5 rows x 30 columns]

# %%
player_stats
# Out:
#       Rk                Player Pos  Age   Tm   G    MP   PER    TS%   3PAr  \
# 0      1  Kareem Abdul-Jabbar*   C   32  LAL  82  3143  25.3  0.639  0.001
# 1      2         Tom Abernethy  PF   25  GSW  67  1222  11.0  0.511  0.003
# 2      3           Alvan Adams   C   25  PHO  75  2168  19.2  0.571  0.002
# 3      4       Tiny Archibald*  PG   31  BOS  80  2864  15.3  0.574  0.023
# 4      5         Dennis Awtrey   C   31  CHI  26   560   7.4  0.524  0.000
# ..   ...                   ...  ..  ...  ...  ..   ...   ...    ...    ...
# 700  536          Delon Wright  PG   28  SAC  27   696  15.9  0.563  0.369
# 701  537        Thaddeus Young  PF   32  CHI  68  1652  20.3  0.578  0.068
# 702  538            Trae Young  PG   22  ATL  63  2125  23.0  0.589  0.357
# 703  539           Cody Zeller   C   28  CHO  48  1005  18.2  0.599  0.086
# 704  540           Ivica Zubac   C   23  LAC  72  1609  19.1  0.693  0.010
#
#      ...  OWS  DWS    WS  WS/48  Unnamed: 24  OBPM  DBPM  BPM  VORP  Year
# 0    ...  9.5  5.3  14.8  0.227          NaN   4.8   2.4  7.2   7.3  1980
# 1    ...  1.2  0.8   2.0  0.080          NaN  -1.0  -0.2 -1.2   0.2  1980
# 2    ...  3.1  3.9   7.0  0.155          NaN   1.7   1.9  3.6   3.1  1980
# 3    ...  5.9  2.9   8.9  0.148          NaN   1.4  -0.3  1.1   2.3  1980
# 4    ...  0.1  0.5   0.6  0.053          NaN  -2.3   0.9 -1.4   0.1  1980
# ..   ...  ...  ...   ...    ...          ...   ...   ...  ...   ...   ...
# 700  ...  0.8  0.5   1.3  0.092          NaN   0.5   0.6  1.2   0.6  2021
# 701  ...  2.8  2.2   5.1  0.147          NaN   1.9   1.4  3.3   2.2  2021
# 702  ...  5.9  1.3   7.2  0.163          NaN   5.3  -1.7  3.7   3.0  2021
# 703  ...  2.1  1.1   3.3  0.156          NaN  -0.2  -0.2 -0.5   0.4  2021
# 704  ...  4.8  2.1   6.9  0.206          NaN   0.6   0.4  1.0   1.2  2021
#
# [21655 rows x 30 columns]

# %%
del player_stats['Unnamed: 19']

# %%
player_stats
# Out:
#       Rk                Player Pos  Age   Tm   G    MP   PER    TS%   3PAr  \
# 0      1  Kareem Abdul-Jabbar*   C   32  LAL  82  3143  25.3  0.639  0.001
# 1      2         Tom Abernethy  PF   25  GSW  67  1222  11.0  0.511  0.003
# 2      3           Alvan Adams   C   25  PHO  75  2168  19.2  0.571  0.002
# 3      4       Tiny Archibald*  PG   31  BOS  80  2864  15.3  0.574  0.023
# 4      5         Dennis Awtrey   C   31  CHI  26   560   7.4  0.524  0.000
# ..   ...                   ...  ..  ...  ...  ..   ...   ...    ...    ...
# 700  536          Delon Wright  PG   28  SAC  27   696  15.9  0.563  0.369
# 701  537        Thaddeus Young  PF   32  CHI  68  1652  20.3  0.578  0.068
# 702  538            Trae Young  PG   22  ATL  63  2125  23.0  0.589  0.357
# 703  539           Cody Zeller   C   28  CHO  48  1005  18.2  0.599  0.086
# 704  540           Ivica Zubac   C   23  LAC  72  1609  19.1  0.693  0.010
#
#      ...  USG%  OWS  DWS    WS  WS/48  OBPM  DBPM  BPM  VORP  Year
# 0    ...  24.1  9.5  5.3  14.8  0.227   4.8   2.4  7.2   7.3  1980
# 1    ...  13.3  1.2  0.8   2.0  0.080  -1.0  -0.2 -1.2   0.2  1980
# 2    ...  21.9  3.1  3.9   7.0  0.155   1.7   1.9  3.6   3.1  1980
# 3    ...  17.0  5.9  2.9   8.9  0.148   1.4  -0.3  1.1   2.3  1980
# 4    ...   7.9  0.1  0.5   0.6  0.053  -2.3   0.9 -1.4   0.1  1980
# ..   ...   ...  ...  ...   ...    ...   ...   ...  ...   ...   ...
# 700  ...  17.1  0.8  0.5   1.3  0.092   0.5   0.6  1.2   0.6  2021
# 701  ...  22.3  2.8  2.2   5.1  0.147   1.9   1.4  3.3   2.2  2021
# 702  ...  33.0  5.9  1.3   7.2  0.163   5.3  -1.7  3.7   3.0  2021
# 703  ...  18.3  2.1  1.1   3.3  0.156  -0.2  -0.2 -0.5   0.4  2021
# 704  ...  15.1  4.8  2.1   6.9  0.206   0.6   0.4  1.0   1.2  2021
#
# [21655 rows x 28 columns]

# %%
player_stats.to_csv("player_advanced_stats.csv")

# %%
player_stats.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'MP', 'PER', 'TS%', '3PAr',
#        'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%',
#        'OWS', 'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP', 'Year'],
#       dtype='object')

# %%
players = pd.read_csv("player_advanced_stats.csv")

# %%
players
# Out:
#        Unnamed: 0   Rk                Player Pos  Age   Tm   G    MP   PER  \
# 0               0    1  Kareem Abdul-Jabbar*   C   32  LAL  82  3143  25.3
# 1               1    2         Tom Abernethy  PF   25  GSW  67  1222  11.0
# 2               2    3           Alvan Adams   C   25  PHO  75  2168  19.2
# 3               3    4       Tiny Archibald*  PG   31  BOS  80  2864  15.3
# 4               4    5         Dennis Awtrey   C   31  CHI  26   560   7.4
# ...           ...  ...                   ...  ..  ...  ...  ..   ...   ...
# 21650         700  536          Delon Wright  PG   28  SAC  27   696  15.9
# 21651         701  537        Thaddeus Young  PF   32  CHI  68  1652  20.3
# 21652         702  538            Trae Young  PG   22  ATL  63  2125  23.0
# 21653         703  539           Cody Zeller   C   28  CHO  48  1005  18.2
# 21654         704  540           Ivica Zubac   C   23  LAC  72  1609  19.1
#
#          TS%  ...  USG%  OWS  DWS    WS  WS/48  OBPM  DBPM  BPM  VORP  Year
# 0      0.639  ...  24.1  9.5  5.3  14.8  0.227   4.8   2.4  7.2   7.3  1980
# 1      0.511  ...  13.3  1.2  0.8   2.0  0.080  -1.0  -0.2 -1.2   0.2  1980
# 2      0.571  ...  21.9  3.1  3.9   7.0  0.155   1.7   1.9  3.6   3.1  1980
# 3      0.574  ...  17.0  5.9  2.9   8.9  0.148   1.4  -0.3  1.1   2.3  1980
# 4      0.524  ...   7.9  0.1  0.5   0.6  0.053  -2.3   0.9 -1.4   0.1  1980
# ...      ...  ...   ...  ...  ...   ...    ...   ...   ...  ...   ...   ...
# 21650  0.563  ...  17.1  0.8  0.5   1.3  0.092   0.5   0.6  1.2   0.6  2021
# 21651  0.578  ...  22.3  2.8  2.2   5.1  0.147   1.9   1.4  3.3   2.2  2021
# 21652  0.589  ...  33.0  5.9  1.3   7.2  0.163   5.3  -1.7  3.7   3.0  2021
# 21653  0.599  ...  18.3  2.1  1.1   3.3  0.156  -0.2  -0.2 -0.5   0.4  2021
# 21654  0.693  ...  15.1  4.8  2.1   6.9  0.206   0.6   0.4  1.0   1.2  2021
#
# [21655 rows x 29 columns]

# %%
players.columns
# Out:
# Index(['Unnamed: 0', 'Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG',
#        'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT',
#        'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF',
#        'PTS', 'Year'],
#       dtype='object')

# %%
players = pd.read_csv("player_per_game_stats.csv")

# %%
players
# Out:
#        Unnamed: 0   Rk                Player Pos  Age   Tm   G    GS    MP  \
# 0               0    1  Kareem Abdul-Jabbar*   C   32  LAL  82   NaN  38.3
# 1               1    2         Tom Abernethy  PF   25  GSW  67   NaN  18.2
# 2               2    3           Alvan Adams   C   25  PHO  75   NaN  28.9
# 3               3    4       Tiny Archibald*  PG   31  BOS  80  80.0  35.8
# 4               4    5         Dennis Awtrey   C   31  CHI  26   NaN  21.5
# ...           ...  ...                   ...  ..  ...  ...  ..   ...   ...
# 21650       21650  536          Delon Wright  PG   28  SAC  27   8.0  25.8
# 21651       21651  537        Thaddeus Young  PF   32  CHI  68  23.0  24.3
# 21652       21652  538            Trae Young  PG   22  ATL  63  63.0  33.7
# 21653       21653  539           Cody Zeller   C   28  CHO  48  21.0  20.9
# 21654       21654  540           Ivica Zubac   C   23  LAC  72  33.0  22.3
#
#          FG  ...  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS  Year
# 0      10.2  ...  2.3  8.5  10.8  4.5  1.0  3.4  3.6  2.6  24.8  1980
# 1       2.3  ...  0.9  1.9   2.9  1.3  0.5  0.2  0.6  1.8   5.4  1980
# 2       6.2  ...  2.1  6.0   8.1  4.3  1.4  0.7  2.9  3.2  14.9  1980
# 3       4.8  ...  0.7  1.7   2.5  8.4  1.3  0.1  3.0  2.7  14.1  1980
# 4       1.0  ...  1.1  3.3   4.4  1.5  0.5  0.6  1.0  2.5   3.3  1980
# ...     ...  ...  ...  ...   ...  ...  ...  ...  ...  ...   ...   ...
# 21650   3.9  ...  1.0  2.9   3.9  3.6  1.6  0.4  1.3  1.1  10.0  2021
# 21651   5.4  ...  2.5  3.8   6.2  4.3  1.1  0.6  2.0  2.2  12.1  2021
# 21652   7.7  ...  0.6  3.3   3.9  9.4  0.8  0.2  4.1  1.8  25.3  2021
# 21653   3.8  ...  2.5  4.4   6.8  1.8  0.6  0.4  1.1  2.5   9.4  2021
# 21654   3.6  ...  2.6  4.6   7.2  1.3  0.3  0.9  1.1  2.6   9.0  2021
#
# [21655 rows x 32 columns]
